# %%
pip install pandas
pip install matplotlib
pip install seaborn
pip install numpy
pip install scipy
pip install scikiy-learn
# Out:
#   Cell In[1], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas
pip install matplotlib
pip install seaborn
pip install numpy
pip install scipy
pip install scikit-learn
# Out:
#   Cell In[2], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas matplotlib seaborn numpy scipy scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
file_path="railway_data_dictionary.csv"
data=pd.read_csv(file_path)
print(data.head())
# Out:
#               Field                                        Description
# 0    Transaction ID  Unique identifier for an individual train tick...
# 1  Date of Purchase                      Date the ticket was purchased
# 2  Time of Purchase                      Time the ticket was purchased
# 3     Purchase Type  Whether the ticket was purchased online or dir...
# 4    Payment Method  Payment method used to purchase the ticket (Co...

# %%
import pandas as pd
file_path="railway_data_dictionary.csv"
data=pd.read_csv(file_path)
data.head()
# Out:
#               Field                                        Description
# 0    Transaction ID  Unique identifier for an individual train tick...
# 1  Date of Purchase                      Date the ticket was purchased
# 2  Time of Purchase                      Time the ticket was purchased
# 3     Purchase Type  Whether the ticket was purchased online or dir...
# 4    Payment Method  Payment method used to purchase the ticket (Co...

# %%
import pandas as pd
file_path="railway.csv"
data=pd.read_csv(file_path)
data.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
import pandas as pd
file_path="railway.csv"
data=pd.read_csv(file_path)
print(data.dtypes)
# Out:
# Transaction ID         object
# Date of Purchase       object
# Time of Purchase       object
# Purchase Type          object
# Payment Method         object
# Railcard               object
# Ticket Class           object
# Ticket Type            object
# Price                   int64
# Departure Station      object
# Arrival Destination    object
# Date of Journey        object
# Departure Time         object
# Arrival Time           object
# Actual Arrival Time    object
# Journey Status         object
# Reason for Delay       object
# Refund Request         object
# dtype: object

# %%
data["Railcard"].unique()
# Out:
# array(['Adult', nan, 'Disabled', 'Senior'], dtype=object)

# %%
data["Railcard"].value_counts()
# Out:
# Railcard
# Adult       4846
# Disabled    3089
# Senior      2800
# Name: count, dtype: int64

# %%
data=data[data["Railcard"]!="Senior"]

# %%
data["Railcard"].value_counts()
# Out:
# Railcard
# Adult       4846
# Disabled    3089
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Transaction ID             0
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard               20918
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1683
# Journey Status             0
# Reason for Delay       24959
# Refund Request             0
# dtype: int64

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
railcard_column=data["Railcard"].values.reshape(-1,1)
data["Railcard"]=imputer.fit_transform(railcard_column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 imputer=SimpleImputer(strategy='most_frequent')
#       4 railcard_column=data["Railcard"].values.reshape(-1,1)
# ----> 5 data["Railcard"]=imputer.fit_transform(railcard_column)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
# ...

# %%
data.isnull().sum()

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
railcard_column=data["Railcard"].values.reshape(-1,1)
data["Railcard"]=imputer.fit_transform(railcard_column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       3 imputer=SimpleImputer(strategy='most_frequent')
#       4 railcard_column=data["Railcard"].values.reshape(-1,1)
# ----> 5 data["Railcard"]=imputer.fit_transform(railcard_column)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Assuming data is already loaded
# data = pd.read_csv('railway.csv')

# Initialize the SimpleImputer with the strategy 'most frequent'
imputer = SimpleImputer(strategy='most_frequent')

# Reshape the "Railcard" column to be a 2D array as required by the imputer
railcard_column = data["Railcard"].values.reshape(-1, 1)

# Fit the imputer on the "Railcard" column and transform it
data["Railcard"] = imputer.fit_transform(railcard_column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 14
#      11 railcard_column = data["Railcard"].values.reshape(-1, 1)
#      13 # Fit the imputer on the "Railcard" column and transform it
# ---> 14 data["Railcard"] = imputer.fit_transform(railcard_column)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
railcard_column=data["Railcard"].values.reshape(-1,1)
data["Railcard"]=imputer.fit_transform(railcard_column).ravel()

# %%
data.isnull().sum()
# Out:
# Transaction ID             0
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard                   0
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1683
# Journey Status             0
# Reason for Delay       24959
# Refund Request             0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path="railway.csv"
data=pd.read_csv(file_path)
plt.hist(data["Price"],bins=10,edgecolor="black",color="orange")
plt.xlabel=("Price")
plt.ylabel=("frequency")
plt.title("Histogram of price varible")
plt.show()

# %%
data["Price"].unique()
# Out:
# array([ 43,  23,   3,  13,  76,  35,   2,  37,   8,  15,   7,  86,  34,
#         57,   5,  10,   4,  12,  33,  70,  16, 134,  29,  47,   6, 151,
#         25,  21,  53,  19,   9,  20,  54,  17,  11,  84,  41, 200,  27,
#         14, 107, 143,  22,  18, 235,  78,  50,  32, 108,  72, 106,  65,
#         24,  52,  67,  90,  31,  48,  39,  59,  44,  95, 144, 114, 118,
#        119,  38, 111,  56, 128, 113,  80, 267,  63,  97,  26, 101,  36,
#        216,  93,  30,  82,  88,  71,  55, 126,  73, 110,  89,  51,  66,
#        168,  69, 162,   1, 135,  28,  45, 129,  42,  49, 176, 180, 157,
#        121,  77, 211, 104, 112,  96, 171, 146, 154,  64, 116, 158, 242,
#        117, 178, 203, 238,  74, 109,  94, 102], dtype=int64)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (31653, 18)

# %%
data.drop_duplicates()
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
data.shape
# Out:
# (31653, 18)

# %%
data["Ticket Type"].unique()
# Out:
# array(['Advance', 'Off-Peak', 'Anytime'], dtype=object)

# %%
#Anytime = 1
#Off-Peak = 2
#Advance = 3

# %%
Ticket_mapping={
"Anytime":1,"Off-Peak":2,"Advance":3}
data["Ticket_Type_encoded"]=data["Ticket Type"].map(Ticket_mapping)

# %%
data
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
data["Price"].min()
data["Price"].max()
# Out:
# 267

# %%
data["Price"].min()
# Out:
# 1

# %%
data["Price"].unique()
# Out:
# array([ 43,  23,   3,  13,  76,  35,   2,  37,   8,  15,   7,  86,  34,
#         57,   5,  10,   4,  12,  33,  70,  16, 134,  29,  47,   6, 151,
#         25,  21,  53,  19,   9,  20,  54,  17,  11,  84,  41, 200,  27,
#         14, 107, 143,  22,  18, 235,  78,  50,  32, 108,  72, 106,  65,
#         24,  52,  67,  90,  31,  48,  39,  59,  44,  95, 144, 114, 118,
#        119,  38, 111,  56, 128, 113,  80, 267,  63,  97,  26, 101,  36,
#        216,  93,  30,  82,  88,  71,  55, 126,  73, 110,  89,  51,  66,
#        168,  69, 162,   1, 135,  28,  45, 129,  42,  49, 176, 180, 157,
#        121,  77, 211, 104, 112,  96, 171, 146, 154,  64, 116, 158, 242,
#        117, 178, 203, 238,  74, 109,  94, 102], dtype=int64)

# %%
bins=[0,50,100,150,200,250,300,float('inf')]
labels=('0 t0 50','50 to 100','100 to 150','150 to 200','200 to 250','250 to 300','300+')
data["Price_category"]=pd.cut(data["Price"],bins=bins,labels=labels,right=False)

# %%
data
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
refund_dummies=pd.get_dummies(data["Refund Request"],prefix="Refund")
data=pd.concat([data,refund_dummies],axis=1)
data
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...
